# %% [markdown]
# # BMV hierarchical dependence pipeline
#
# Publication/reproducibility notebook. Code is organized into sequential modules under `src/` for reviewability.

# %%
# %pip install -q -r requirements.txt

# %%
from pathlib import Path
for module in sorted(Path("src").glob("cell_*.py")):
    print(f"Executing {module}")
    exec(compile(module.read_text(encoding="utf-8"), str(module), "exec"), globals())

# %%
results = run_pipeline(CFG)
